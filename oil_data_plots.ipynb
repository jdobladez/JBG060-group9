# %% [markdown]
# ### Uses data from World Bank and Kaggle
#
# <br>https://www.kaggle.com/datasets/shawkatsujon/worldwide-fuel-production-and-consumption/</br>
# <br>https://www.eia.gov/dnav/pet/hist/RBRTED.htm</br>
# <br>https://data.worldbank.org/country/south-sudan</br>

# %%
import pandas as pd
import numpy as np
import dash
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# %%
oil_production = pd.read_csv("data/Fuel production vs consumption.csv", encoding='unicode_escape')
oil_production.head(100)
# Out:
#     Year       Entity  Gas production(m³)  Gas consumption(m³)  \
# 0   1980  Afghanistan        1.699000e+09         5.664000e+07
# 1   1981  Afghanistan        2.237000e+09         8.496000e+07
# 2   1982  Afghanistan        2.294000e+09         1.416000e+08
# 3   1983  Afghanistan        2.407000e+09         1.416000e+08
# 4   1984  Afghanistan        2.407000e+09         1.416000e+08
# ..   ...          ...                 ...                  ...
# 95  1984      Algeria        3.852000e+10         1.926000e+10
# 96  1985      Algeria        3.852000e+10         1.654000e+10
# 97  1986      Algeria        3.767000e+10         1.705000e+10
# 98  1987      Algeria        4.319000e+10         1.858000e+10
# 99  1988      Algeria        4.630000e+10         2.016000e+10
#
#     Coal production(Ton)  Coal consumption(Ton)  Oil production(m³)  \
# 0               119000.0               119000.0                 0.0
# 1               125000.0               125000.0                 0.0
# 2               145000.0               145000.0                 0.0
# 3               145000.0               145000.0                 0.0
# 4               148000.0               148000.0                 0.0
# ..                   ...                    ...                 ...
# 95               22750.0              1247000.0          58910000.0
# 96               23000.0              1247000.0          60160000.0
# 97               11000.0              1260000.0          62250000.0
# 98                9500.0              1277000.0          62210000.0
# 99               10000.0              1296000.0          60680000.0
#
#     Oil consumption(m³)  Gas production per capita(m³)  \
# 0              406500.0                          127.2
# 1              464600.0                          169.9
# 2              452900.0                          178.1
# 3              638800.0                          192.0
# 4              638800.0                          197.2
# ..                  ...                            ...
# 95            8710000.0                         1770.0
# 96            9582000.0                         1717.0
# 97            9651000.0                         1630.0
# 98            9721000.0                         1817.0
# 99           10030000.0                         1894.0
#
#     Gas consumption per capita(m³)  Coal production per capita(Ton)  \
# 0                            4.241                         0.008910
# 1                            6.450                         0.009490
# 2                           10.990                         0.011260
# 3                           11.290                         0.011570
# 4                           11.600                         0.012130
# ..                             ...                              ...
# 95                         884.900                         0.001045
# 96                         737.300                         0.001025
# 97                         738.000                         0.000476
# 98                         781.400                         0.000400
# 99                         824.900                         0.000409
#
#     Coal consumption per capita(Ton)  Oil production per capita(m³)  \
# 0                            0.00891                          0.000
# 1                            0.00949                          0.000
# 2                            0.01126                          0.000
# 3                            0.01157                          0.000
# 4                            0.01213                          0.000
# ..                               ...                            ...
# 95                           0.05730                          2.707
# 96                           0.05560                          2.682
# 97                           0.05453                          2.695
# 98                           0.05371                          2.617
# 99                           0.05301                          2.483
#
#     Oil consumption per capita(m³)  Population
# 0                          0.03043  13360000.0
# 1                          0.03527  13170000.0
# 2                          0.03516  12880000.0
# 3                          0.05095  12540000.0
# 4                          0.05234  12200000.0
# ..                             ...         ...
# 95                         0.40020  21760000.0
# 96                         0.42710  22430000.0
# 97                         0.41780  23100000.0
# 98                         0.40890  23770000.0
# 99                         0.41030  24440000.0
#
# [100 rows x 15 columns]

# %%
ssd_data = oil_production[oil_production['Entity'] == "South Sudan"]
ssd_data
# Out:
#       Year       Entity  Gas production(m³)  Gas consumption(m³)  \
# 7612  2012  South Sudan                 0.0                  0.0
# 7613  2013  South Sudan                 0.0                  0.0
# 7614  2014  South Sudan                 0.0                  0.0
# 7615  2015  South Sudan                 0.0                  0.0
# 7616  2016  South Sudan                 0.0                  0.0
# 7617  2017  South Sudan                 0.0                  0.0
# 7618  2018  South Sudan                 0.0                  0.0
# 7619  2019  South Sudan                 0.0                  0.0
# 7620  2020  South Sudan                 0.0                  0.0
#
#       Coal production(Ton)  Coal consumption(Ton)  Oil production(m³)  \
# 7612                   0.0                    0.0           1325000.0
# 7613                   0.0                    0.0           6723000.0
# 7614                   0.0                    0.0           8581000.0
# 7615                   0.0                    0.0           8864000.0
# 7616                   0.0                    0.0           8853000.0
# 7617                   0.0                    0.0           8718000.0
# 7618                   0.0                    0.0           9047000.0
# 7619                   0.0                    0.0           9123000.0
# 7620                   0.0                    0.0           9438000.0
#
#       Oil consumption(m³)  Gas production per capita(m³)  \
# 7612             563800.0                            0.0
# 7613             596800.0                            0.0
# 7614             617400.0                            0.0
# 7615             758400.0                            0.0
# 7616             731200.0                            0.0
# 7617             641000.0                            0.0
# 7618             659100.0                            0.0
# 7619             750300.0                            0.0
# 7620                  NaN                            0.0
#
#       Gas consumption per capita(m³)  Coal production per capita(Ton)  \
# 7612                             0.0                              0.0
# 7613                             0.0                              0.0
# 7614                             0.0                              0.0
# 7615                             0.0                              0.0
# 7616                             0.0                              0.0
# 7617                             0.0                              0.0
# 7618                             0.0                              0.0
# 7619                             0.0                              0.0
# 7620                             0.0                              0.0
#
#       Coal consumption per capita(Ton)  Oil production per capita(m³)  \
# 7612                               0.0                         0.1310
# 7613                               0.0                         0.6492
# 7614                               0.0                         0.8130
# 7615                               0.0                         0.8272
# 7616                               0.0                         0.8173
# 7617                               0.0                         0.7990
# 7618                               0.0                         0.8242
# 7619                               0.0                         0.8247
# 7620                               0.0                         0.8432
#
#       Oil consumption per capita(m³)  Population
# 7612                         0.05575  10110000.0
# 7613                         0.05763  10360000.0
# 7614                         0.05850  10550000.0
# 7615                         0.07078  10720000.0
# 7616                         0.06750  10830000.0
# 7617                         0.05875  10910000.0
# 7618                         0.06005  10980000.0
# 7619                         0.06782  11060000.0
# 7620                             NaN  11190000.0

# %%
colors_2 = {'Production':px.colors.qualitative.Plotly[5],
          'Consumption':px.colors.qualitative.Plotly[6]}

prod_cons = go.Figure()

prod_cons.add_traces(go.Scatter(x=ssd_data['Year'], y = ssd_data['Oil production(m³)'], name="Oil Production",
                         marker_color=colors_2['Production']))
prod_cons.add_traces(go.Scatter(x=ssd_data['Year'], y = ssd_data['Oil consumption(m³)'], name="Oil Consumption",
                         marker_color=colors_2['Consumption']))
prod_cons.update_layout(
    title="Oil Production vs. Consumption in South Sudan",
    xaxis_title="Year",
    yaxis_title="Volume (m³)",
)
prod_cons.show()

# %%
oil_prices = pd.read_excel('data\RBRTEd.xls', sheet_name='Data 1',engine="xlrd", header=2)
oil_prices.rename(columns={"Europe Brent Spot Price FOB (Dollars per Barrel)": "Price per Barrel ($)"}, inplace=True)
oil_prices
# Out:
#            Date  Price per Barrel ($)
# 0    1987-05-20                 18.63
# 1    1987-05-21                 18.45
# 2    1987-05-22                 18.55
# 3    1987-05-25                 18.60
# 4    1987-05-26                 18.63
# ...         ...                   ...
# 9231 2023-10-04                 89.83
# 9232 2023-10-05                 88.28
# 9233 2023-10-06                 87.86
# 9234 2023-10-09                 91.37
# 9235 2023-10-10                 90.70
#
# [9236 rows x 2 columns]

# %%
oil_price_fig = px.line(oil_prices, "Date", "Price per Barrel ($)", title='Oil Price Growth Over the Years')
oil_price_fig.show()

# %%
electricity_generated = pd.read_csv("data\electricity_production_from_oil.csv", header=2)
electricity_generated = electricity_generated.drop(axis="columns", labels="Unnamed: 67")
electricity_generated = electricity_generated.melt(id_vars=['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code'], var_name="Year", value_name="Percentage")
electricity_generated.sort_values(ascending=True, by=['Country Name', 'Year'], inplace=True)
electricity_generated
# Out:
#       Country Name Country Code  \
# 2      Afghanistan          AFG
# 268    Afghanistan          AFG
# 534    Afghanistan          AFG
# 800    Afghanistan          AFG
# 1066   Afghanistan          AFG
# ...            ...          ...
# 15693     Zimbabwe          ZWE
# 15959     Zimbabwe          ZWE
# 16225     Zimbabwe          ZWE
# 16491     Zimbabwe          ZWE
# 16757     Zimbabwe          ZWE
#
#                                           Indicator Name  Indicator Code  \
# 2      Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 268    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 534    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 800    Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 1066   Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# ...                                                  ...             ...
# 15693  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 15959  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 16225  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 16491  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
# 16757  Electricity production from oil sources (% of ...  EG.ELC.PETR.ZS
#
#        Year  Percentage
# 2      1960         NaN
# 268    1961         NaN
# 534    1962         NaN
# 800    1963         NaN
# 1066   1964         NaN
# ...     ...         ...
# 15693  2018         NaN
# 15959  2019         NaN
# 16225  2020         NaN
# 16491  2021         NaN
# 16757  2022         NaN
#
# [16758 rows x 6 columns]

# %%
electricity_gen_oil = px.line(electricity_generated[electricity_generated['Country Code']=="SSD"].dropna(), "Year", "Percentage", title='Percentage of Electricity Production from Oil Sources')
electricity_gen_oil.show()

# %%
affected_country = ['Iraq','Libya','Congo Republic','Kuwait','South Sudan','Saudi Arabia','Oman','Equatorial Guinea','Azerbaijan','Angola','Iran','Gabon','Timor-Leste','Qatar','UAE']
oil_rent = [37.8,37.3,36.7,36.6,31.3,23.1,21.8,19.2,17.9,15.8,15.3,15.3,14.5,14.2,13.1]
affected_country = affected_country[::-1]
oil_rent = oil_rent[::-1]


fig = go.Figure(go.Bar(
            x=oil_rent,
            y=affected_country,
            orientation='h',
            text = oil_rent,
            textposition='auto'))
fig.update_traces(marker_color='purple')

fig.update_layout(title=go.layout.Title(text="<b>Countries Heavily Dependent on Oil Profits to Power GDP</b>"))
fig.update_layout(annotations=[
       go.layout.Annotation(
            showarrow=False,
            text='Source: World Bank',
            xanchor='right',
            x=35,
            xshift=275,
            yanchor='top',
            y=0.05,
        )])

# fig['layout']['xaxis'].update(side='top')

fig.show()

# %%
oil_revenue = pd.read_excel('data\South_Sudan_Oil_Revenue.xlsx', sheet_name='Sheet1',engine="openpyxl")
oil_revenue["Date"] = pd.to_datetime(oil_revenue["Date"], format="%Y_%m") # Create date column
oil_revenue
# Out:
#           Date  Oil_revenue  Net_sales  Barels_sold
# 0   2011-07-01       305.70        NaN         3.10
# 1   2011-08-01       528.70        NaN         5.50
# 2   2011-09-01       674.90        NaN         6.70
# 3   2011-10-01       618.00        NaN         6.20
# 4   2011-11-01       560.40        NaN         5.30
# ..         ...          ...        ...          ...
# 114 2021-01-01        29.86      29.86         0.57
# 115 2021-02-01        78.40      78.40         1.26
# 116 2021-03-01        79.30      79.30         1.20
# 117 2021-04-01       113.23     113.23         1.77
# 118 2021-05-01       123.42     123.42         1.79
#
# [119 rows x 4 columns]

# %%
food_updated = pd.read_csv("data/food_crises_month_imputed.csv")
food_updated
# Out:
#         datetime      country  district_code district     centx     centy  \
# 0     2009-07-01  South Sudan             74      Bor  32.00486  6.465644
# 1     2009-08-01  South Sudan             74      Bor  32.00486  6.465644
# 2     2009-09-01  South Sudan             74      Bor  32.00486  6.465644
# 3     2009-10-01  South Sudan             74      Bor  32.00486  6.465644
# 4     2009-11-01  South Sudan             74      Bor  32.00486  6.465644
# ...          ...          ...            ...      ...       ...       ...
# 9979  2019-10-01  South Sudan            151  Malakal  31.64280  9.658457
# 9980  2019-11-01  South Sudan            151  Malakal  31.64280  9.658457
# 9981  2019-12-01  South Sudan            151  Malakal  31.64280  9.658457
# 9982  2020-01-01  South Sudan            151  Malakal  31.64280  9.658457
# 9983  2020-02-01  South Sudan            151  Malakal  31.64280  9.658457
#
#      year_month  year  month  ipc  ...  food_price_idx        area  \
# 0       2009_07  2009      7  2.0  ...        1.098674  14008.3300
# 1       2009_08  2009      8  2.0  ...        1.171685  14008.3300
# 2       2009_09  2009      9  2.0  ...        1.194245  14008.3300
# 3       2009_10  2009     10  2.0  ...        1.185251  14008.3300
# 4       2009_11  2009     11  2.0  ...        1.197838  14008.3300
# ...         ...   ...    ...  ...  ...             ...         ...
# 9979    2019_10  2019     10  3.0  ...       82.872570    757.7855
# 9980    2019_11  2019     11  3.0  ...       87.728720    757.7855
# 9981    2019_12  2019     12  3.0  ...       93.566750    757.7855
# 9982    2020_01  2020      1  4.0  ...      106.793600    757.7855
# 9983    2020_02  2020      2  4.0  ...      113.214100    757.7855
#
#       cropland_pct       pop  ruggedness_mean  pasture_pct        date  \
# 0         7.961984  256618.0        11393.760      90.8503  2009-07-01
# 1         7.961984  256618.0        11393.760      90.8503  2009-08-01
# 2         7.961984  256618.0        11393.760      90.8503  2009-09-01
# 3         7.961984  256618.0        11393.760      90.8503  2009-10-01
# 4         7.961984  256618.0        11393.760      90.8503  2009-11-01
# ...            ...       ...              ...          ...         ...
# 9979     13.068690  102228.0         7145.909      85.5000  2019-10-01
# 9980     13.068690  102228.0         7145.909      85.5000  2019-11-01
# 9981     13.068690  102228.0         7145.909      85.5000  2019-12-01
# 9982     13.068690  163171.3         7145.909      85.5000  2020-01-01
# 9983     13.068690  163171.3         7145.909      85.5000  2020-02-01
#
#                 province  administrative_region  quarters
# 0     Greater Upper Nile     Greater Upper Nile    2009Q3
# 1     Greater Upper Nile     Greater Upper Nile    2009Q3
# 2     Greater Upper Nile     Greater Upper Nile    2009Q3
# 3     Greater Upper Nile     Greater Upper Nile    2009Q4
# 4     Greater Upper Nile     Greater Upper Nile    2009Q4
# ...                  ...                    ...       ...
# 9979  Greater Upper Nile     Greater Upper Nile    2019Q4
# 9980  Greater Upper Nile     Greater Upper Nile    2019Q4
# 9981  Greater Upper Nile     Greater Upper Nile    2019Q4
# 9982  Greater Upper Nile     Greater Upper Nile    2020Q1
# 9983  Greater Upper Nile     Greater Upper Nile    2020Q1
#
# [9984 rows x 29 columns]

# %%
colors = {'1':px.colors.qualitative.Plotly[0],
          '2':px.colors.qualitative.Plotly[1],
          '3':px.colors.qualitative.Plotly[2],
          '4':px.colors.qualitative.Plotly[3],
          '5':px.colors.qualitative.Plotly[4]}

a = food_updated[food_updated['ipc'].isna() == False]
a['ipc'] = a['ipc'].astype('int')
a = a.sort_values(by=['year','ipc'], ascending=True)
a['ipc'] = a['ipc'].astype('string')
b = a[['year', 'ipc']].value_counts()
c = b.to_frame(name='count')
d = c.reset_index()

# Create figure with secondary y-axis
fig_comb = make_subplots(specs=[[{"secondary_y": True}]])

fig_comb.add_trace(go.Scatter(x=oil_revenue["Date"], y=oil_revenue["Oil_revenue"], marker_color='black',
                              name="Revenue"), secondary_y=True)

for r in d['ipc'].unique():
    dfp = d[d['ipc']==r]
    fig_comb.add_trace(go.Bar(x=dfp['year'], y = dfp['count'], name=r,
                         marker_color=colors[r]), secondary_y=False)

fig_comb.update_layout(
    title_text="Impact of Oil Revenue on IPC Rating"
)  
fig_comb.update_xaxes(title_text="Year")
fig_comb.update_yaxes(title_text="Oil Revenue in Millions ($)", secondary_y=True)
fig_comb.update_yaxes(title_text="IPC count", secondary_y=False)

fig_comb.show()

# %%
fig_rev_net = go.Figure()
fig_rev_net.add_traces(go.Scatter(x=oil_revenue["Date"], y=oil_revenue["Oil_revenue"],
                              name="Gross Revenue")) 
fig_rev_net.add_traces(go.Scatter(x=oil_revenue["Date"], y=oil_revenue["Net_sales"],
                              name="Net Revenue"))
fig_rev_net.update_layout(
    title="Proportion of Gross and Net Oil Revenue",
    xaxis_title="Year",
    yaxis_title="Revenue in Millions ($)",
)
fig_rev_net.show()
