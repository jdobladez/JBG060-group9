# %% [markdown]
# # Guided Topic Modeling
# This technique guides the topic modeling approach by setting several seed topics to which the model will converge to.
#
# <u>Warning</u>: BERTopic is merely nudged towards creating those topics. In practice, if the seeded topics do not exist or might be divided into smaller topics, then they will not be modeled. Thus, seed topics need to be accurate to accurately converge towards them.
#
# Read more about it [here](https://maartengr.github.io/BERTopic/getting_started/guided/guided.html).
#
# <b>Results</b>: Technique was implemented successfully and it did improve slightly (about 300 more articles categorized), however, we believe that the potential of using this technique is higher if appropriate research is done and better, more accurate seed topics are fed. We encourage ZHL to further investigate

# %%
import pandas as pd
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
from bertopic import BERTopic
import os

# %%
# Read the data and perform preprocessing
df = pd.read_csv("data/articles_summary_cleaned.csv", parse_dates=["date"]) # Read data into 'df' dataframe
print(df.shape) # Print dataframe shape

docs = df["summary"].tolist() # Create a list containing all article summaries

df.head() # Show first 5 dataframe entries
# Out:
# (18520, 5)
#                                              summary       date  \
# 0  The article discusses the passing of the new C... 2011-07-07
# 1  The article discusses the military actions tak... 2011-07-03
# 2  The article discusses the signing of a Framewo... 2011-06-30
# 3  The article discusses the upcoming independenc... 2011-07-04
# 4  The article discusses the need for South Sudan... 2011-07-02
#
#     location_article        lat        lng
# 0               Juba   4.859363  31.571250
# 1              Abyei   9.838551  28.486396
# 2  Southern Kordofan  11.036544  30.895824
# 3        South Sudan   6.876992  31.306979
# 4               Juba   4.859363  31.571250

# %%
if os.path.exists('guided_model'):
    guided_bertopic = BERTopic.load('guided_model')
else:
    # Create a list of seed topics
    seed_topics = [["corruption", "governance", "political instability", "leadership crisis", "failed state"],  # Political
               ["oil production", "china", "india", "resource exploitation", "oil revenues", "resource curse"],  # Oil
               ["hunger", "food security", "poverty", "famine", "food aid", "livelihoods", "food crisis"],  # Food Insecurity
               ["migration", "refugees", "displacement", "asylum", "internal displacement", "IDPs", "returnees"],  # Refugee
               ["humanitarian", "health", "education", "aid and development", "NGOs", "UN agencies", "humanitarian crisis"],  # Human Aid
               ["peace and security", "conflict", "violence", "civil war", "ethnic conflict", "peace process", "insecurity"],  # Conflict
               ["terrorism", "extremism", "armed groups", "rebel forces", "insurgency", "extremist organizations"],  # Terrorism
               ["climate", "flood", "drought", "environment", "climate change", "natural disasters", "environmental degradation"],  # Climate causes
               ["livestock", "cattle", "animals", "herding", "pastoralism", "livestock diseases", "livestock health", "livestock markets"]]  # Livestock


    guided_bertopic = BERTopic(language="english", calculate_probabilities=True, verbose=True, seed_topic_list = seed_topics) # Initialize the BERTopic model
    topics, _ = guided_bertopic.fit_transform(docs)
    guided_bertopic.save("guided_model") # Save the trained model as "guided_trial_model"

# %%
guided_bertopic.visualize_documents(docs)

# %%
guided_bertopic.visualize_topics()

# %%
guided_bertopic.generate_topic_labels()
# Out:
# ['-1_and_the_in',
#  '0_independence_author_tribalism',
#  '1_oil_pipeline_production',
#  '2_journalists_media_freedom',
#  '3_abyei_referendum_area',
#  '4_border_zone_agreements',
#  '5_cabinet_governor_speaker',
#  '6_albashir_president_visit',
#  '7_party_splm_liberation',
#  '8_refugees_unhcr_refugee',
#  '9_humanitarian_aid_million',
#  '10_kiir_author_leadership',
#  '11_church_churches_bishop',
#  '12_transitional_unity_machar',
#  '13_lakes_rumbek_dhuol',
#  '14_china_chinese_chinas',
#  '15_murle_lou_jonglei',
#  '16_heglig_panthou_withdraw',
#  '17_human_rights_commission',
#  '18_corruption_anticorruption_money',
#  '19_food_famine_hunger',
#  '20_detainees_release_trial',
#  '21_deal_agreement_machar',
#  '22_uhuru_kenyatta_kenyattas',
#  '23_arms_embargo_weapons',
#  '24_traders_ugandan_trade',
#  '25_refugees_uganda_refugee',
#  '26_updf_ugandas_troops',
#  '27_cup_match_football',
#  '28_children_child_soldiers',
#  '29_igad_talks_intergovernmental',
#  '30_signing_peace_revolutionary',
#  '31_sanctions_us_individuals',
#  '32_saf_jau_bombing',
#  '33_eac_east_join',
#  '34_education_higher_students',
#  '35_agriculture_agricultural_food',
#  '36_cholera_outbreak_cases',
#  '37_malakal_town_upper',
#  '38_peacebuilding_peace_society',
#  '39_women_womens_gender',
#  '40_displaced_idps_internally',
#  '41_oil_production_cooperation',
#  '42_amnesty_ssla_spla',
#  '43_currency_bank_pound',
#  '44_returnees_kosti_iom',
#  '45_igad_intergovernmental_authority',
#  '46_sexual_violence_women',
#  '47_wfp_food_assistance',
#  '48_border_kordofan_blue',
#  '49_nationality_passports_citizenship',
#  '50_investment_investors_business',
#  '51_museveni_musevenis_yoweri',
#  '52_unmiss_mandate_mission',
#  '53_bor_jonglei_capital',
#  '54_lra_kony_lords',
#  '55_food_hunger_insecurity',
#  '56_workers_aid_humanitarian',
#  '57_flooding_floods_flood',
#  '58_polio_vaccination_campaign',
#  '59_police_interior_enforcement',
#  '60_federalism_federal_system',
#  '61_malaria_disease_health',
#  '62_police_officers_rwanda',
#  '63_msf_medical_patients',
#  '64_fao_food_seeds',
#  '65_conflict_machar_nuer',
#  '66_itu_internet_network',
#  '67_covid19_virus_cases',
#  '68_dam_egypt_renaissance',
#  '69_icc_court_arrest',
#  '70_coup_curfew_machar',
#  '71_court_hybrid_justice',
#  '72_kerry_kerrys_secretary',
#  '73_cattle_raiders_cows',
#  '74_jal_music_film',
#  '75_drivers_highway_truck',
#  '76_humanitarian_pibor_jonglei',
#  '77_relations_cooperation_bilateral',
#  '78_ramciel_capital_housing',
#  '79_kenyans_kenyan_kenyatta',
#  '80_basin_water_egypt',
#  '81_force_troops_deployment',
#  '82_abraham_isaiah_murder',
#  '83_ondieki_commander_mogoa',
#  '84_bank_banks_kcb',
#  '85_arusha_tanzania_splm',
#  '86_egypts_egypt_egyptian',
#  '87_education_school_schools',
#  '88_reconciliation_healing_process',
#  '89_wau_protests_bagari',
#  '90_constitution_constitutional_review',
#  '91_eritrean_eritrea_isaias',
#  '92_ambassadors_diplomatic_embassies',
#  '93_health_healthcare_drugs',
#  '94_malong_paul_gen',
#  '95_road_roads_construction',
#  '96_jem_equality_justice',
#  '97_red_icrc_cross',
#  '98_sentry_report_corruption',
#  '99_talks_ababa_addis',
#  '100_girls_marriage_child',
#  '101_darfur_unamid_300000',
#  '102_mombasa_port_corridor',
#  '103_commission_inquiry_olusegun',
#  '104_ban_kimoon_secretarygeneral',
#  '105_university_students_administration',
#  '106_almahdi_party_nup',
#  '107_public_service_capacity',
#  '108_demarcation_border_joint',
#  '109_splmn_kordofan_blue',
#  '110_football_sports_olympic',
#  '111_hiv_hivaids_testing',
#  '112_bentiu_rebels_control',
#  '113_japanese_japan_japans',
#  '114_us_ambassador_booth',
#  '115_elections_election_census',
#  '116_youth_sports_conference',
#  '117_igga_wani_james',
#  '118_budget_spending_ssp',
#  '119_prices_price_inflation',
#  '120_gunfire_heavy_juba',
#  '121_ramaphosas_cyril_ramaphosa',
#  '122_rwanda_rdf_peacekeeping',
#  '123_corruption_transparency_scored',
#  '124_jonglei_peace_conference',
#  '125_school_education_exams',
#  '126_ebola_health_disease',
#  '127_ceasefire_signing_agreement',
#  '128_refugees_migrants_asylum',
#  '129_buhari_muhammadu_buharis',
#  '130_penalty_death_executions',
#  '131_city_mayor_plastic',
#  '132_kakuma_refugee_camp',
#  '133_disarmament_jonglei_guns',
#  '134_2018_peace_unified',
#  '135_machar_machars_kiirs',
#  '136_kenyans_evacuation_kenyan',
#  '137_malnutrition_children_unicef',
#  '138_zenawi_meles_zenawis',
#  '139_jonglei_violence_civilians',
#  '140_flights_airways_airline',
#  '141_workers_jobs_foreign',
#  '142_obamas_obama_us',
#  '143_austerity_measures_salaries',
#  '144_land_grabbing_lease',
#  '145_blairs_british_discussed',
#  '146_children_unicef_families',
#  '147_summit_african_ababa',
#  '148_au_aus_african',
#  '149_tax_collection_revenue',
#  '150_disappearance_family_luis',
#  '151_pension_pensioners_pensions',
#  '152_civilians_unmiss_bases',
#  '153_yau_david_yaus',
#  '154_nuba_mountains_wolf',
#  '155_plane_crash_landing',
#  '156_bill_powers_nss',
#  '157_gambella_ethiopian_gambela',
#  '158_her_murder_sister',
#  '159_livestock_animal_cattle',
#  '160_water_supply_drinking',
#  '161_bentiu_civilians_killed',
#  '162_helicopter_crew_russian',
#  '163_athor_george_morobo',
#  '164_electricity_power_grid',
#  '165_unamid_darfur_peacekeepers',
#  '166_nuer_massacre_dinka',
#  '167_basketball_qualifiers_fiba',
#  '168_medical_machar_machars',
#  '169_darfur_doha_ddpd',
#  '170_midwives_maternal_health',
#  '171_language_arabic_english',
#  '172_police_officers_training',
#  '173_ddr_excombatants_reintegration',
#  '174_oil_machars_riek',
#  '175_omer_albashir_bashir',
#  '176_equatoria_equatorians_greater',
#  '177_supporting_army_kordofan',
#  '178_embassy_us_citizens',
#  '179_aviation_airlines_airline',
#  '180_yau_pibor_david',
#  '181_fuel_petrol_trucks',
#  '182_covid19_health_oxygen',
#  '183_fire_brigade_hotel',
#  '184_league_youth_splm',
#  '185_icglr_great_angola',
#  '186_imf_monetary_fund',
#  '187_education_ecw_children',
#  '188_bank_world_afdb',
#  '189_drivers_uganda_ugandans',
#  '190_lanzer_toby_humanitarian',
#  '191_attack_convoy_un',
#  '192_telar_ring_deng',
#  '193_joint_committee_meetings',
#  '194_vocational_training_labour',
#  '195_bill_reading_legislative',
#  '196_water_drought_climate',
#  '197_detainees_talks_ababa',
#  '198_disarmament_abuses_jonglei',
#  '199_israel_israeli_jerusalem',
#  '200_johnson_hilde_her',
#  '201_bentiu_conditions_flooding',
#  '202_vaccine_doses_vaccines',
#  '203_gai_gatluak_matip',
#  '204_bus_accident_driver',
#  '205_opportunities_east_business',
#  '206_civilians_ethnic_crimes',
#  '207_forum_partners_partnership',
#  '208_nyandeng_warrap_malek',
#  '209_ban_kimoon_un',
#  '210_bahr_ghazal_army',
#  '211_mine_landmines_unexploded',
#  '212_aturjong_dau_defection',
#  '213_martyrs_day_veterans',
#  '214_trade_transport_smuggling',
#  '215_fragile_index_ranked',
#  '216_icc_bashir_arrest',
#  '217_mabuzas_revitalised_mabuza',
#  '218_54th_member_admission',
#  '219_wildlife_poaching_park',
#  '220_governor_equatoria_cabinet',
#  '221_abyei_aupsc_panel',
#  '222_ethiopias_abiy_somalia',
#  '223_child_children_labour',
#  '224_debt_debts_external',
#  '225_athuai_deng_alliance',
#  '226_textbooks_books_primary',
#  '227_troika_norway_kingdom',
#  '228_bombs_cluster_use',
#  '229_blood_health_canadas',
#  '230_ibrahim_meriam_apostasy',
#  '231_splmn_kordofan_north',
#  '232_truce_positions_attacking',
#  '233_weapons_firearms_wau',
#  '234_judiciary_judges_judicial',
#  '235_tons_metric_deliver',
#  '236_sudd_institute_foster',
#  '237_eac_admission_market',
#  '238_civil_lives_personal']

# %%
# We create a function to calculate a list of the top n topics related to (a) given keyword(s)

def get_relevant_topics(bertopic_model, keywords, top_n):
    '''
    Retrieve a list of the top n number of relevant topics to the provided (list of) keyword(s)


    Parameters:
        bertopic_model: a (fitted) BERTopic model object

        keywords:   a string containing one or multiple keywords to match against,

                    This can also be a list in the form of ['keyword(s)', keyword(s), ...]

                    In this case a maximum of top_n topics will be found per list element
                    and subsetted to the top_n most relevant topics.

                    # !!!
                    Take care that this method only considers the relevancy per inputted keyword(s)
                    and not the relevancy to the combined list of keywords.

                    In other words, topics that appear in the output might be significantly related to a
                    particular element in the list of keywords but not so to any other element,

                    while topics that do not appear in the output might be significantly related to the
                    combined list of keywords but not much to any of the keyword(s) in particular.
                    # !!!

        top_n: an integer indicating the number of desired relevant topics to be retrieved


        Return: a list of the top_n (or less) topics most relevant to the (list of) provided keyword(s)
    '''

    if type(keywords) is str: keywords = [keywords] # If a single string is provided convert it to list type

    relevant_topics = list() # Initilize an empty list of relevant topics

    for keyword in keywords: # Iterate through list of keywords

        # Find the top n number of topics related to the current keyword(s)
        topics = bertopic_model.find_topics(keyword, top_n = top_n)

        # Add the topics to the list of relevant topics in the form of (topic_id, relevancy)
        relevant_topics.extend(
            zip(topics[0], topics[1]) # topics[0] = topic_id, topics[1] = relevancy
        )


    relevant_topics.sort(key=lambda x: x[1]) # Sort the list of topics on ASCENDING ORDER of relevancy

    # Get a list of the set of unique topics (with greates relevancy in case of duplicate topics)
    relevant_topics = list(dict(relevant_topics).items())


    relevant_topics.sort(key=lambda x: x[1], reverse=True) # Now sort the list of topics on DESCENDING ORDER of relevancy

    return relevant_topics[:10] # Return a list of the top_n unique relevant topics

# %% [markdown]
# # Livestock

# %%
# Get the top 10 topics related to the keywords 'cattle', 'livestock', 'animals'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['cattle', 'livestock', 'animals'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["livestock"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 159 0.67029715
# 73 0.57171
# 219 0.4856301
# 35 0.47053766
# 64 0.4285058
# 55 0.41244912
# 47 0.3668123
# 13 0.35744536
# 19 0.34786773
# 24 0.32890373
#        Count                                      Name  \
# Topic
# 159       21       159_livestock_animal_cattle_animals
# 73        44           73_cattle_raiders_cows_rustling
# 219       12   219_wildlife_poaching_park_conservation
# 35        84  35_agriculture_agricultural_food_farmers
# 64        52                    64_fao_food_seeds_kits
# 55        63         55_food_hunger_insecurity_farmers
# 47        69              47_wfp_food_assistance_world
# 13       146            13_lakes_rumbek_dhuol_governor
# 19       107             19_food_famine_hunger_million
# 24       100           24_traders_ugandan_trade_uganda
#
#                                           Representation  \
# Topic
# 159    [livestock, animal, cattle, animals, diseases,...
# 73     [cattle, raiders, cows, rustling, warrap, raid...
# 219    [wildlife, poaching, park, conservation, eleph...
# 35     [agriculture, agricultural, food, farmers, far...
# 64     [fao, food, seeds, kits, million, livelihood, ...
# 55     [food, hunger, insecurity, farmers, million, w...
# 47     [wfp, food, assistance, world, programme, mill...
# 13     [lakes, rumbek, dhuol, governor, chut, matur, ...
# 19     [food, famine, hunger, million, crisis, starva...
# 24     [traders, ugandan, trade, uganda, market, comp...
#
#                                      Representative_Docs
# Topic
# 159    [The article discusses how 13 months of civil ...
# 73     [The article discusses a clash between police ...
# 219    [The article discusses the increase in wildlif...
# 35     [The article discusses the need for cooperatio...
# 64     [The article discusses FAO's efforts to provid...
# 55     [The article discusses the findings of a new C...
# 47     [The article discusses the European Commission...
# 13     [The article discusses the death of Colonel Yo...
# 19     [The article discusses how extreme hunger is a...
# 24     [The article discusses how the government of U...

# %% [markdown]
# # Corruption

# %%
# Get the top 10 topics related to the keywords 'corruption' and 'coup'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['corruption', 'coup'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["corruption"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 123 0.795946
# 18 0.5801017
# 98 0.4768626
# 149 0.3980472
# 79 0.3964479
# 225 0.39140248
# 144 0.36744428
# 10 0.35612983
# 20 0.35333145
# 131 0.3499308
#        Count                                          Name  \
# Topic
# 123       28  123_corruption_transparency_scored_plaintiff
# 18       120  18_corruption_anticorruption_money_officials
# 98        35           98_sentry_report_corruption_illicit
# 149       22              149_tax_collection_revenue_taxes
# 79        43               79_kenyans_kenyan_kenyatta_were
# 225       12           225_athuai_deng_alliance_kidnapping
# 144       23                 144_land_grabbing_lease_issue
# 10       193                10_kiir_author_leadership_nuer
# 20       106            20_detainees_release_trial_treason
# 131       26                131_city_mayor_plastic_garbage
#
#                                           Representation  \
# Topic
# 123    [corruption, transparency, scored, plaintiff, ...
# 18     [corruption, anticorruption, money, officials,...
# 98     [sentry, report, corruption, illicit, mel, dol...
# 149    [tax, collection, revenue, taxes, finance, cen...
# 79     [kenyans, kenyan, kenyatta, were, four, famili...
# 225    [athuai, deng, alliance, kidnapping, society, ...
# 144    [land, grabbing, lease, issue, grabbers, equat...
# 10     [kiir, author, leadership, nuer, his, kiirs, p...
# 20     [detainees, release, trial, treason, prisoners...
# 131    [city, mayor, plastic, garbage, cleaning, clea...
#
#                                      Representative_Docs
# Topic
# 123    [The article discusses the definition of corru...
# 18     [The article discusses South Sudan's President...
# 98     [The article discusses the release of a new in...
# 149    [The article discusses the Republic of South S...
# 79     [The article discusses how families of four Ke...
# 225    [The article discusses the shooting of Deng At...
# 144    [The article discusses the issue of land grabb...
# 10     [The article discusses the political crisis in...
# 20     [The article discusses the release of seven So...
# 131    [The article discusses young South Sudanese wh...

# %% [markdown]
# # Oil Production

# %%
# Get the top 10 topics related to the keywords 'oil', 'petrolium', 'china' and 'india'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['oil', 'china', 'india'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["oil"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 41 0.43788797
# 1 0.4376254
# 174 0.39840442
# 14 0.39138252
# 181 0.36217442
# 215 0.3026979
# 119 0.278493
# 113 0.2638155
# 66 0.24643165
# 175 0.24450883
#        Count                                     Name  \
# Topic
# 41        78  41_oil_production_cooperation_countries
# 1        378           1_oil_pipeline_production_fees
# 174       18              174_oil_machars_riek_machar
# 14       146          14_china_chinese_chinas_beijing
# 181       17         181_fuel_petrol_trucks_petroleum
# 215       13            215_fragile_index_ranked_most
# 119       29     119_prices_price_inflation_beverages
# 113       31    113_japanese_japan_japans_engineering
# 66        50              66_itu_internet_network_mtn
# 175       18        175_omer_albashir_bashir_khartoum
#
#                                           Representation  \
# Topic
# 41     [oil, production, cooperation, countries, resu...
# 1      [oil, pipeline, production, fees, crude, trans...
# 174    [oil, machars, riek, machar, revenues, reserve...
# 14     [china, chinese, chinas, beijing, oil, visit, ...
# 181    [fuel, petrol, trucks, petroleum, shortage, su...
# 215    [fragile, index, ranked, most, fsi, ffp, world...
# 119    [prices, price, inflation, beverages, goods, c...
# 113    [japanese, japan, japans, engineering, tokyo, ...
# 66     [itu, internet, network, mtn, code, cable, tel...
# 175    [omer, albashir, bashir, khartoum, kordofan, h...
#
#                                      Representative_Docs
# Topic
# 41     [The article discusses a meeting held in Khart...
# 1      [The article discusses the release of impounde...
# 174    [The article discusses the major offensive lau...
# 14     [The article discusses the inauguration of the...
# 181    [The article discusses how the ministry of pet...
# 215    [The article discusses the release of the Frag...
# 119    [The article discusses a decrease in inflation...
# 113    [The article discusses the establishment of a ...
# 66     [The article discusses the signing of a memora...
# 175    [The article discusses the threat of war by Su...

# %% [markdown]
# # Hunger

# %%
# Get the top 10 topics related to the keywords 'hunger' and 'food insecurity'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['hunger', 'food insecurity'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["hunger"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 55 0.65119267
# 19 0.4918156
# 64 0.47771373
# 137 0.43900698
# 47 0.43301296
# 35 0.35561422
# 146 0.32271755
# 235 0.2837204
# 159 0.2780196
# 9 0.27740264
#        Count                                            Name  \
# Topic
# 55        63               55_food_hunger_insecurity_farmers
# 19       107                   19_food_famine_hunger_million
# 64        52                          64_fao_food_seeds_kits
# 137       24  137_malnutrition_children_unicef_breastfeeding
# 47        69                    47_wfp_food_assistance_world
# 35        84        35_agriculture_agricultural_food_farmers
# 146       23            146_children_unicef_families_million
# 235       10            235_tons_metric_deliver_humanitarian
# 159       21             159_livestock_animal_cattle_animals
# 9        209           9_humanitarian_aid_million_assistance
#
#                                           Representation  \
# Topic
# 55     [food, hunger, insecurity, farmers, million, w...
# 19     [food, famine, hunger, million, crisis, starva...
# 64     [fao, food, seeds, kits, million, livelihood, ...
# 137    [malnutrition, children, unicef, breastfeeding...
# 47     [wfp, food, assistance, world, programme, mill...
# 35     [agriculture, agricultural, food, farmers, far...
# 146    [children, unicef, families, million, malnutri...
# 235    [tons, metric, deliver, humanitarian, delivery...
# 159    [livestock, animal, cattle, animals, diseases,...
# 9      [humanitarian, aid, million, assistance, fundi...
#
#                                      Representative_Docs
# Topic
# 55     [The article discusses the findings of a new C...
# 19     [The article discusses how extreme hunger is a...
# 64     [The article discusses FAO's efforts to provid...
# 137    [The article discusses the severe acute malnut...
# 47     [The article discusses the European Commission...
# 35     [The article discusses the need for cooperatio...
# 146    [The article discusses how violence and insecu...
# 235    [The article discusses the opening of a humani...
# 159    [The article discusses how 13 months of civil ...
# 9      [The article discusses the United States' anno...

# %% [markdown]
# # Migration

# %%
# Get the top 10 topics related to the keywords 'refugees', 'displaced' and 'flee'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['refugees', 'displaced', 'flee'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["refugees"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 128 0.81677043
# 25 0.68290854
# 8 0.6551687
# 132 0.6215856
# 40 0.5845568
# 201 0.5435972
# 152 0.52415866
# 44 0.5093847
# 136 0.4976229
# 146 0.49740756
#        Count                                     Name  \
# Topic
# 128       26     128_refugees_migrants_asylum_israeli
# 25       100      25_refugees_uganda_refugee_district
# 8        210            8_refugees_unhcr_refugee_nile
# 132       25         132_kakuma_refugee_camp_refugees
# 40        80      40_displaced_idps_internally_people
# 201       15      201_bentiu_conditions_flooding_camp
# 152       22  152_civilians_unmiss_bases_peacekeeping
# 44        72      44_returnees_kosti_iom_repatriation
# 136       24     136_kenyans_evacuation_kenyan_flight
# 146       23     146_children_unicef_families_million
#
#                                           Representation  \
# Topic
# 128    [refugees, migrants, asylum, israeli, israel, ...
# 25     [refugees, uganda, refugee, district, adjumani...
# 8      [refugees, unhcr, refugee, nile, yida, camp, a...
# 132    [kakuma, refugee, camp, refugees, kenya, camps...
# 40     [displaced, idps, internally, people, displace...
# 201    [bentiu, conditions, flooding, camp, base, peo...
# 152    [civilians, unmiss, bases, peacekeeping, un, r...
# 44     [returnees, kosti, iom, repatriation, migratio...
# 136    [kenyans, evacuation, kenyan, flight, national...
# 146    [children, unicef, families, million, malnutri...
#
#                                      Representative_Docs
# Topic
# 128    [The article discusses Israeli Prime Minister ...
# 25     [The article discusses the launch of a regiona...
# 8      [The article discusses the concerns expressed ...
# 132    [The article discusses the influx of refugees ...
# 40     [The article discusses the high number of inte...
# 201    [The article discusses the dire humanitarian s...
# 152    [The article discusses new fighting in South S...
# 44     [The article discusses the arrival of the last...
# 136    [The article discusses the evacuation of Kenya...
# 146    [The article discusses how violence and insecu...

# %% [markdown]
# # Humanitarian

# %%
# Get the top 10 topics related to the keyword 'humanitarian'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['humanitarian'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["humanitarian"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 187 0.67556524
# 229 0.6606716
# 190 0.64318967
# 76 0.64160997
# 9 0.64067316
# 56 0.6112286
# 40 0.60082227
# 152 0.6005495
# 201 0.5981987
# 97 0.5817331
#        Count                                      Name  \
# Topic
# 187       17         187_education_ecw_children_global
# 229       11       229_blood_health_canadas_healthcare
# 190       17  190_lanzer_toby_humanitarian_coordinator
# 76        44    76_humanitarian_pibor_jonglei_affected
# 9        209     9_humanitarian_aid_million_assistance
# 56        63        56_workers_aid_humanitarian_worker
# 40        80       40_displaced_idps_internally_people
# 152       22   152_civilians_unmiss_bases_peacekeeping
# 201       15       201_bentiu_conditions_flooding_camp
# 97        36                    97_red_icrc_cross_ifrc
#
#                                           Representation  \
# Topic
# 187    [education, ecw, children, global, school, pay...
# 229    [blood, health, canadas, healthcare, hospital,...
# 190    [lanzer, toby, humanitarian, coordinator, mr, ...
# 76     [humanitarian, pibor, jonglei, affected, aid, ...
# 9      [humanitarian, aid, million, assistance, fundi...
# 56     [workers, aid, humanitarian, worker, killing, ...
# 40     [displaced, idps, internally, people, displace...
# 152    [civilians, unmiss, bases, peacekeeping, un, r...
# 201    [bentiu, conditions, flooding, camp, base, peo...
# 97     [red, icrc, cross, ifrc, medical, care, cresce...
#
#                                      Representative_Docs
# Topic
# 187    [The article discusses the passing of Congress...
# 229    [The article discusses the inauguration of the...
# 190    [The article discusses a press briefing with t...
# 76     [The article discusses the aid distribution op...
# 9      [The article discusses the United States' anno...
# 56     [The article discusses the disappearance of si...
# 40     [The article discusses the high number of inte...
# 152    [The article discusses new fighting in South S...
# 201    [The article discusses the dire humanitarian s...
# 97     [The article discusses the International Feder...

# %% [markdown]
# # Conflict

# %%
# Get the top 10 topics related to the keywords 'conflict', 'fighting', 'murder' and 'troops'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['conflict', 'fighting', 'murder', 'troops'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["conflict"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 158 0.44024155
# 232 0.4298405
# 81 0.42673117
# 54 0.41361254
# 173 0.40674824
# 48 0.4008087
# 26 0.39658153
# 99 0.38852888
# 28 0.38664374
# 122 0.3857227
#        Count                                        Name  \
# Topic
# 158       21                  158_her_murder_sister_shot
# 232       11          232_truce_positions_attacking_army
# 81        42       81_force_troops_deployment_protection
# 54        64                54_lra_kony_lords_resistance
# 173       19  173_ddr_excombatants_reintegration_program
# 48        68                48_border_kordofan_blue_both
# 26        99              26_updf_ugandas_troops_ugandan
# 99        34                  99_talks_ababa_addis_round
# 28        97      28_children_child_soldiers_recruitment
# 122       28    122_rwanda_rdf_peacekeeping_peacekeepers
#
#                                           Representation  \
# Topic
# 158    [her, murder, sister, shot, veronika, was, rac...
# 232    [truce, positions, attacking, army, upper, opp...
# 81     [force, troops, deployment, protection, peacek...
# 54     [lra, kony, lords, resistance, joseph, central...
# 173    [ddr, excombatants, reintegration, program, de...
# 48     [border, kordofan, blue, both, accusations, su...
# 26     [updf, ugandas, troops, ugandan, withdrawal, u...
# 99     [talks, ababa, addis, round, peace, ethiopia, ...
# 28     [children, child, soldiers, recruitment, unice...
# 122    [rwanda, rdf, peacekeeping, peacekeepers, rwan...
#
#                                      Representative_Docs
# Topic
# 158    [The article discusses the call made by Bishop...
# 232    [The article discusses the accusation made by ...
# 81     [The article discusses the deployment of troop...
# 54     [The article discusses the end of the six-year...
# 173    [The article discusses the plans of the South ...
# 48     [The article discusses the upcoming presidenti...
# 26     [The article discusses the withdrawal of Ugand...
# 99     [The article discusses the final round of peac...
# 28     [The article discusses the United Nations Spec...
# 122    [The article discusses the four-day official v...

# %% [markdown]
# # Terrorism

# %%
# Get the top 10 topics related to the keywords 'terrorism'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['terrorism'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["terrorism"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 161 0.4508683
# 191 0.4389815
# 139 0.43733042
# 32 0.43284658
# 206 0.4307009
# 228 0.42565465
# 233 0.4194704
# 157 0.40761083
# 154 0.39486194
# 165 0.39259413
#        Count                                        Name  \
# Topic
# 161       21        161_bentiu_civilians_killed_killings
# 191       16                 191_attack_convoy_un_unmiss
# 139       24  139_jonglei_violence_civilians_communities
# 32        87                   32_saf_jau_bombing_aerial
# 206       15        206_civilians_ethnic_crimes_killings
# 228       11             228_bombs_cluster_use_munitions
# 233       10            233_weapons_firearms_wau_marking
# 157       21       157_gambella_ethiopian_gambela_attack
# 154       21               154_nuba_mountains_wolf_wolfs
# 165       20       165_unamid_darfur_peacekeepers_abeche
#
#                                           Representation  \
# Topic
# 161    [bentiu, civilians, killed, killings, mosque, ...
# 191    [attack, convoy, un, unmiss, peacekeepers, inv...
# 139    [jonglei, violence, civilians, communities, un...
# 32     [saf, jau, bombing, aerial, attacks, armed, fo...
# 206    [civilians, ethnic, crimes, killings, ethnicit...
# 228    [bombs, cluster, use, munitions, remnants, fou...
# 233    [weapons, firearms, wau, marking, unauthorized...
# 157    [gambella, ethiopian, gambela, attack, childre...
# 154    [nuba, mountains, wolf, wolfs, frank, obama, r...
# 165    [unamid, darfur, peacekeepers, abeche, khor, p...
#
#                                      Representative_Docs
# Topic
# 161    [The article discusses the United Nations' con...
# 191    [The article discusses an attack on a U.N. con...
# 139    [The article discusses the ongoing ethnic viol...
# 32     [The article discusses the condemnation by the...
# 206    [The article discusses how both sides in South...
# 228    [The article discusses how Human Rights Watch ...
# 233    [The article discusses South Sudan's interior ...
# 157    [The article discusses armed men from the Murl...
# 154    [The article discusses the bombing of civilian...
# 165    [The article discusses the review of the situa...

# %% [markdown]
# # Climate

# %%
# Get the top 10 topics related to the keywords 'flooding' and 'droughts'
relevant_topics = get_relevant_topics(bertopic_model = guided_bertopic, keywords=['flooding', 'droughts'], top_n=15)

topic_ids = [el[0] for el in relevant_topics] # Create seperate list of topic IDs

for topic_id, relevancy in relevant_topics: # Print neat list of (topic_id, relevancy) tuples
    print(topic_id, relevancy)

df["nature"] = [t in topic_ids for t in guided_bertopic.topics_] # Add boolean column to df if topic in list of relevant topics

# View the Count, Name, Representation, and Representative Docs for the relevant topics
guided_bertopic.get_topic_info().set_index('Topic').loc[topic_ids]
# Out:
# 196 0.63046366
# 57 0.55128306
# 160 0.36778143
# 201 0.33107322
# 55 0.2890054
# 19 0.28028253
# 68 0.27285278
# 80 0.27004346
# 13 0.26021403
# 36 0.24976525
#        Count                                 Name  \
# Topic
# 196       16   196_water_drought_climate_flooding
# 57        61    57_flooding_floods_flood_affected
# 160       21    160_water_supply_drinking_project
# 201       15  201_bentiu_conditions_flooding_camp
# 55        63    55_food_hunger_insecurity_farmers
# 19       107        19_food_famine_hunger_million
# 68        49       68_dam_egypt_renaissance_grand
# 80        42            80_basin_water_egypt_nile
# 13       146       13_lakes_rumbek_dhuol_governor
# 36        84     36_cholera_outbreak_cases_health
#
#                                           Representation  \
# Topic
# 196    [water, drought, climate, flooding, horn, dipo...
# 57     [flooding, floods, flood, affected, rains, peo...
# 160    [water, supply, drinking, project, clean, dise...
# 201    [bentiu, conditions, flooding, camp, base, peo...
# 55     [food, hunger, insecurity, farmers, million, w...
# 19     [food, famine, hunger, million, crisis, starva...
# 68     [dam, egypt, renaissance, grand, gerd, ethiopi...
# 80     [basin, water, egypt, nile, irrigation, projec...
# 13     [lakes, rumbek, dhuol, governor, chut, matur, ...
# 36     [cholera, outbreak, cases, health, hygiene, sp...
#
#                                      Representative_Docs
# Topic
# 196    [The article discusses how climate change may ...
# 57     [The article discusses the distribution of aid...
# 160    [The article discusses the water crisis in Jub...
# 201    [The article discusses the dire humanitarian s...
# 55     [The article discusses the findings of a new C...
# 19     [The article discusses how extreme hunger is a...
# 68     [The article discusses the meeting of irrigati...
# 80     [The article discusses Minister of Water Resou...
# 13     [The article discusses the death of Colonel Yo...
# 36     [The article discusses the outbreak of cholera...

# %% [markdown]
# # Saving

# %%
original_df = pd.read_csv('data/articles_summary_cleaned.csv', parse_dates=["date"])

# Combine article summaries with the newly created features
df = original_df.merge(
    df[["summary", "hunger", "refugees", "humanitarian", "conflict", "corruption", "terrorism", "nature", 'oil','livestock']],
    how="left",
    left_on="summary",
    right_on="summary",
)
df.to_csv("articles_topics.csv", index=False) # Save DataFrame to articles_topics.csv

# %%
print(len(df))
print(len(df[(df["hunger"]==False) & (df["refugees"] == False) & (df["humanitarian"] == False) & (df["conflict"] == False) & (df["corruption"] == False) & (df["terrorism"] == False) & (df["nature"] == False) & (df["oil"] == False)& (df["livestock"] == False)]))
# Out:
# 18520
# 14406
